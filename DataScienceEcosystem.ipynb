# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook outlines the essential programming languages, libraries, and open-source tools used in data science, providing a demonstration of the Data Science Ecosystem.

# %% [markdown]
# The course highlights the importance of understanding the Data Scientist’s toolkit - the collection of tools, programming languages, libraries, APIs, datasets, and models that power data work. Framing the introduction around this “toolkit” and the broader data science “ecosystem” accurately captures the full scope of what the course covers. This notebook functions as a final project, showcasing mastery of these essential components.
#
# **Objectives:**
#
# - List popular languages used in Data Science
# - Identify commonly used Data Science libraries
# - Create tables and headings using Markdown
# - Demonstrate basic arithmetic expressions in Python
# - Understand key components of the Data Scientist’s toolkit

# %% [markdown]
#  Some of the popular languages that Data Scientists use are:
#
#  1. Python - the most widely used language for analytics, modeling, and machine learning
#  2. R - preferred for statistical analysis and visualization
#  3. SQL - essential for working with relational databases
#  4. Java & Scala - used in big data ecosystems like Apache Spark
#  5. Julia - emerging for high-performance numerical computing

# %% [markdown]
#  Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas - data manipulation and analysis
# 2. NumPy - numerical computing
# 3. Matplotlib & Seaborn - data visualization
# 4. Scikit-learn - machine learning
# 5. TensorFlow & PyTorch - deep learning
# 6. SciPy - scientific computing

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Visual Studio Code |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Akhil Namdeo

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
